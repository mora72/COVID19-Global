# %%
import pandas as pd
import numpy as np 
df = pd.read_excel('DT1_PAINEL_COVIDBR_20200512.xlsx')

# %%
# df
df[df.municipio =='Uberlândia']
# Out:
#         regiao estado   municipio  coduf    codmun  codRegiaoSaude  \
# 39878  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39879  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39880  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39881  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39882  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39883  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39884  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39885  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39886  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39887  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39888  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39889  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# 39890  Sudeste     MG  Uberlândia     31  317020.0         31073.0
# ...
